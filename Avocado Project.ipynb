# %% [markdown]
# # Import Necessary Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

import warnings
warnings.filterwarnings('ignore')

# %%
avo = pd.read_csv(r"avocado.csv")
avo.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#    year  region
# 0  2015  Albany
# 1  2015  Albany
# 2  2015  Albany
# 3  2015  Albany
# 4  2015  Albany

# %%
# Dropping unnamed column
avo.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
avo.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %% [markdown]
# This dataset contains the detalls of Avocado salses in which both numerical and categorical data are present. Here "type" is the target variable which contains 2 categories so it will be termed as "Classification problem" where we need to predict the several "Type" using the classification models.

# %% [markdown]
# ### Project Description
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.
#
# Some relevant columns in the dataset:
#
# •	Date - The date of the observation
#
# •	AveragePrice - the average price of a single avocado
#
# •	type - conventional or organic
#
# •	year - the year
#
# •	Region - the city or region of the observation
#
# •	Total Volume - Total number of avocados sold
#
# •	4046 - Total number of avocados with PLU 4046 sold
#
# •	4225 - Total number of avocados with PLU 4225 sold
#
# •	4770 - Total number of avocados with PLU 4770 sold
#
# ### Inspiration /Label
#
# The dataset can be seen in two angles to find the region and find the average price.
#
# Task: One of Classification and other of Regression
#
# Do both tasks in the same .ipynb file and submit at single file.

# %% [markdown]
# ### Now we are going to do non Graphical Analysis

# %%
avo.head(20)
# Out:
#           Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0   2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1   2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2   2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3   2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4   2015-11-29          1.28      51039.60   941.48   43838.39   75.78
# 5   2015-11-22          1.26      55979.78  1184.27   48067.99   43.61
# 6   2015-11-15          0.99      83453.76  1368.92   73672.72   93.26
# 7   2015-11-08          0.98     109428.33   703.75  101815.36   80.00
# 8   2015-11-01          1.02      99811.42  1022.15   87315.57   85.34
# 9   2015-10-25          1.07      74338.76   842.40   64757.44  113.00
# 10  2015-10-18          1.12      84843.44   924.86   75595.85  117.07
# 11  2015-10-11          1.28      64489.17  1582.03   52677.92  105.32
# 12  2015-10-04          1.31      61007.10  2268.32   49880.67  101.36
# 13  2015-09-27          0.99     106803.39  1204.88   99409.21  154.84
# 14  2015-09-20          1.33      69759.01  1028.03   59313.12  150.50
# 15  2015-09-13          1.28      76111.27   985.73   65696.86  142.00
# 16  2015-09-06          1.11      99172.96   879.45   90062.62  240.79
# 17  2015-08-30          1.07     105693.84   689.01   94362.67  335.43
# 18  2015-08-23          1.34      79992.09   733.16   67933.79  444.78
# 19  2015-08-16          1.33      80043.78   539.65   68666.01  394.90
#
#     Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  \
# 0      8696.87     8603.62       93.25          0.0  conventional  2015
# 1      9505.56     9408.07       97.49          0.0  conventional  2015
# 2      8145.35     8042.21      103.14          0.0  conventional  2015
# 3      5811.16     5677.40      133.76          0.0  conventional  2015
# 4      6183.95     5986.26      197.69          0.0  conventional  2015
# 5      6683.91     6556.47      127.44          0.0  conventional  2015
# 6      8318.86     8196.81      122.05          0.0  conventional  2015
# 7      6829.22     6266.85      562.37          0.0  conventional  2015
# 8     11388.36    11104.53      283.83          0.0  conventional  2015
# 9      8625.92     8061.47      564.45          0.0  conventional  2015
# 10     8205.66     7877.86      327.80          0.0  conventional  2015
# 11    10123.90     9866.27      257.63          0.0  conventional  2015
# 12     8756.75     8379.98      376.77          0.0  conventional  2015
# 13     6034.46     5888.87      145.59          0.0  conventional  2015
# 14     9267.36     8489.10      778.26          0.0  conventional  2015
# 15     9286.68     8665.19      621.49          0.0  conventional  2015
# 16     7990.10     7762.87      227.23          0.0  conventional  2015
# 17    10306.73    10218.93       87.80          0.0  conventional  2015
# 18    10880.36    10745.79      134.57          0.0  conventional  2015
# 19    10443.22    10297.68      145.54          0.0  conventional  2015
#
#     region
# 0   Albany
# 1   Albany
# 2   Albany
# 3   Albany
# 4   Albany
# 5   Albany
# 6   Albany
# 7   Albany
# 8   Albany
# 9   Albany
# 10  Albany
# 11  Albany
# 12  Albany
# 13  Albany
# 14  Albany
# 15  Albany
# 16  Albany
# 17  Albany
# 18  Albany
# 19  Albany

# %%
avo.tail()
# Out:
#              Date  AveragePrice  Total Volume     4046     4225    4770  \
# 18244  2018-02-04          1.63      17074.83  2046.96  1529.20    0.00
# 18245  2018-01-28          1.71      13888.04  1191.70  3431.50    0.00
# 18246  2018-01-21          1.87      13766.76  1191.92  2452.79  727.94
# 18247  2018-01-14          1.93      16205.22  1527.63  2981.04  727.01
# 18248  2018-01-07          1.62      17489.58  2894.77  2356.13  224.53
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags     type  year  \
# 18244    13498.67    13066.82      431.85          0.0  organic  2018
# 18245     9264.84     8940.04      324.80          0.0  organic  2018
# 18246     9394.11     9351.80       42.31          0.0  organic  2018
# 18247    10969.54    10919.54       50.00          0.0  organic  2018
# 18248    12014.15    11988.14       26.01          0.0  organic  2018
#
#                  region
# 18244  WestTexNewMexico
# 18245  WestTexNewMexico
# 18246  WestTexNewMexico
# 18247  WestTexNewMexico
# 18248  WestTexNewMexico

# %% [markdown]
# # Exploratory Data Analysis(EDA)

# %%
# Checking the dimension of dataset
avo.shape
# Out:
# (18249, 13)

# %% [markdown]
# This dataset contains 18249 rows and 13 columns. Out of which one is target variable and remaining 12 are independent variables

# %%
avo.columns
# Out:
# Index(['Date', 'AveragePrice', 'Total Volume', '4046', '4225', '4770',
#        'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type', 'year',
#        'region'],
#       dtype='object')

# %%
avo.columns.tolist()
# Out:
# ['Date',
#  'AveragePrice',
#  'Total Volume',
#  '4046',
#  '4225',
#  '4770',
#  'Total Bags',
#  'Small Bags',
#  'Large Bags',
#  'XLarge Bags',
#  'type',
#  'year',
#  'region']

# %%
avo.dtypes
# Out:
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# There are three difrent type of data(Int64,float64,object) present in the dataset

# %%
avo.isnull().sum()
# Out:
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          18249 non-null  object
#  1   AveragePrice  18249 non-null  float64
#  2   Total Volume  18249 non-null  float64
#  3   4046          18249 non-null  float64
#  4   4225          18249 non-null  float64
#  5   4770          18249 non-null  float64
#  6   Total Bags    18249 non-null  float64
#  7   Small Bags    18249 non-null  float64
#  8   Large Bags    18249 non-null  float64
#  9   XLarge Bags   18249 non-null  float64
#  10  type          18249 non-null  object
#  11  year          18249 non-null  int64
#  12  region        18249 non-null  object
# dtypes: float64(9), int64(1), object(3)
# memory usage: 1.8+ MB

# %% [markdown]
# As we can see there is no null value present in this dataset.

# %%
#Lets visualize it usning heatmap
sns.heatmap(avo.isnull())
# Out:
# <Axes: >

# %% [markdown]
# We can clearly visualize that there is no missing data present.

# %%
avo['AveragePrice'].nunique()
# Out:
# 259

# %%
for i in avo.columns:
    print(avo[i].value_counts())
    print('\n')
# Out:
# 2015-12-27    108
# 2017-12-24    108
# 2017-12-10    108
# 2017-12-03    108
# 2017-11-26    108
#              ...
# 2016-11-06    108
# 2018-01-07    108
# 2017-06-18    107
# 2017-06-25    107
# 2015-12-06    107
# Name: Date, Length: 169, dtype: int64
#
#
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64
#
#
# 4103.97       2
# 3529.44       2
# 46602.16      2
# 13234.04      2
# 3713.49       2
#              ..
# 874349.55     1
# 1621253.97    1
# 830499.38     1
# 845065.66     1
# 17489.58      1
# Name: Total Volume, Length: 18237, dtype: int64
#
#
# 0.00       242
# 3.00        10
# 4.00         8
# 1.24         8
# 1.00         8
#           ...
# 1486.31      1
# 1761.80      1
# 1772.26      1
# 1803.39      1
# 2894.77      1
# Name: 4046, Length: 17702, dtype: int64
#
#
# 0.00         61
# 177.87        3
# 215.36        3
# 1.30          3
# 1.26          3
#              ..
# 417905.67     1
# 275986.91     1
# 277789.30     1
# 378155.00     1
# 2356.13       1
# Name: 4225, Length: 18103, dtype: int64
#
#
# 0.00      5497
# 2.66         7
# 3.32         7
# 10.97        6
# 1.59         6
#           ...
# 547.08       1
# 155.87       1
# 72.01        1
# 128.06       1
# 224.53       1
# Name: 4770, Length: 12071, dtype: int64
#
#
# 0.00         15
# 990.00        5
# 300.00        5
# 550.00        4
# 266.67        4
#              ..
# 90196.05      1
# 130858.02     1
# 510679.10     1
# 84522.00      1
# 12014.15      1
# Name: Total Bags, Length: 18097, dtype: int64
#
#
# 0.00        159
# 203.33       11
# 223.33       10
# 533.33       10
# 123.33        8
#            ...
# 14002.00      1
# 32441.00      1
# 29560.96      1
# 22077.20      1
# 11988.14      1
# Name: Small Bags, Length: 17321, dtype: int64
#
#
# 0.00          2370
# 3.33           187
# 6.67            78
# 10.00           47
# 4.44            38
#               ...
# 2528089.14       1
# 2287449.76       1
# 731388.25        1
# 673464.14        1
# 26.01            1
# Name: Large Bags, Length: 15082, dtype: int64
#
#
# 0.00       12048
# 3.33          29
# 6.67          16
# 1.11          15
# 5.00          12
#            ...
# 3018.05        1
# 2739.44        1
# 9301.67        1
# 8640.00        1
# 24.18          1
# Name: XLarge Bags, Length: 5588, dtype: int64
#
#
# conventional    9126
# organic         9123
# Name: type, dtype: int64
#
#
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64
#
#
# Albany                 338
# Sacramento             338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# SanDiego               338
# Atlanta                338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# NewYork                338
# NewOrleansMobile       338
# Nashville              338
# Midsouth               338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# WestTexNewMexico       335
# Name: region, dtype: int64

# %% [markdown]
# There is no many missing or null value present in this data.

# %%
categor_col = []
for i in avo.dtypes.index:
    if avo.dtypes[i] == "object":
        categor_col.append(i)
print("Categorical Columns: ", categor_col)
print("\n")

numerical_col = []
for i in avo.dtypes.index:
    if avo.dtypes[i] != "object":
        numerical_col.append(i)
print("Numerical Columns: ", numerical_col)
# Out:
# Categorical Columns:  ['Date', 'type', 'region']
#
#
# Numerical Columns:  ['AveragePrice', 'Total Volume', '4046', '4225', '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'year']

# %%
# Checking number of unique value in each columns
avo.nunique().to_frame("No. of Unique values")
# Out:
#               No. of Unique values
# Date                           169
# AveragePrice                   259
# Total Volume                 18237
# 4046                         17702
# 4225                         18103
# 4770                         12071
# Total Bags                   18097
# Small Bags                   17321
# Large Bags                   15082
# XLarge Bags                   5588
# type                             2
# year                             4
# region                          54

# %%
avo.shape
# Out:
# (18249, 13)

# %% [markdown]
# These are the unique values present in the dataset. Here Total Volume column has the data of unique ID to the customers which can be dropped.

# %%
avo.head()
# Out:
#          Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0  2015-12-27          1.33      64236.62  1036.74   54454.85   48.16
# 1  2015-12-20          1.35      54876.98   674.28   44638.81   58.33
# 2  2015-12-13          0.93     118220.22   794.70  109149.67  130.50
# 3  2015-12-06          1.08      78992.15  1132.00   71976.41   72.58
# 4  2015-11-29          1.28      51039.60   941.48   43838.39   75.78
#
#    Total Bags  Small Bags  Large Bags  XLarge Bags          type  year  region
# 0     8696.87     8603.62       93.25          0.0  conventional  2015  Albany
# 1     9505.56     9408.07       97.49          0.0  conventional  2015  Albany
# 2     8145.35     8042.21      103.14          0.0  conventional  2015  Albany
# 3     5811.16     5677.40      133.76          0.0  conventional  2015  Albany
# 4     6183.95     5986.26      197.69          0.0  conventional  2015  Albany

# %%
avo['type'].unique()
# Out:
# array(['conventional', 'organic'], dtype=object)

# %% [markdown]
# There are two categories presentin the target variable namely "conventional" and "organic"

# %% [markdown]
# ## Types of Avocados:
# In this section we will analyze the different types of avocados that we have in this dataset. Basically, we have two types of avocados:
# #### ->Conventional
# #### ->Organic
# ### Summary:
# ### Organic avocados:-
# Based on the price changes throughout time we can see that they are more expensive.
# ### Conventional avocados:-
# Based on price changes throughout time we can see that they are less expensive.

# %%
# Checking the unique value in Traget column
avo['type'].value_counts()
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# # Description of Dataset

# %%
avo.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count  18249.000000  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean       1.405978  8.506440e+05  2.930084e+05  2.951546e+05  2.283974e+04
# std        0.402677  3.453545e+06  1.264989e+06  1.204120e+06  1.074641e+05
# min        0.440000  8.456000e+01  0.000000e+00  0.000000e+00  0.000000e+00
# 25%        1.100000  1.083858e+04  8.540700e+02  3.008780e+03  0.000000e+00
# 50%        1.370000  1.073768e+05  8.645300e+03  2.906102e+04  1.849900e+02
# 75%        1.660000  4.329623e+05  1.110202e+05  1.502069e+05  6.243420e+03
# max        3.250000  6.250565e+07  2.274362e+07  2.047057e+07  2.546439e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          year
# count  1.824900e+04  1.824900e+04  1.824900e+04   18249.000000  18249.000000
# mean   2.396392e+05  1.821947e+05  5.433809e+04    3106.426507   2016.147899
# std    9.862424e+05  7.461785e+05  2.439660e+05   17692.894652      0.939938
# min    0.000000e+00  0.000000e+00  0.000000e+00       0.000000   2015.000000
# 25%    5.088640e+03  2.849420e+03  1.274700e+02       0.000000   2015.000000
# 50%    3.974383e+04  2.636282e+04  2.647710e+03       0.000000   2016.000000
# 75%    1.107834e+05  8.333767e+04  2.202925e+04     132.500000   2017.000000
# max    1.937313e+07  1.338459e+07  5.719097e+06  551693.650000   2018.000000

# %% [markdown]
# This gives the statistical information of the numerical columns. The summary of the dataset looks perfect since there is no negative/invalid values present.
#
# From the above description we can observe the following:-
#
# 1-The counts of all the columns are same which means there are no missing values in the dataset.
#
# 2-The mean value is greater than the median (50%) in tenure and XLarge Bags columns which means the data is skewed to right in these column.
#
# 3- The data in the column XLarge Bags have mean value less than mean which means the data is skewed to left
#
# 4- By summarizing the data we can observe there is a huge differences between 75% and max hence there are outliers present in the data.
#
# 5-We can also notice the Standard deviation, min, 25% percentile values from this describe method.

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ### Univariate Analysis

# %%
# Visualize the type of avocados
ax = sns.countplot(x = 'type', data = avo)
print(avo['type'].value_counts())
# Out:
# conventional    9126
# organic         9123
# Name: type, dtype: int64

# %% [markdown]
# We can observe that the count of "conventional" and "organic" are equaly distributed

# %%
# Visializinng the AveragePrice of Avocados
ax = sns.countplot(x = 'AveragePrice', data = avo)
print(avo['AveragePrice'].value_counts())
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
# PREPROCESSING

# Rename undefined columns;
avo = avo.rename(index=str, columns={"4046" : "Small Hass", "4225" : "Large Hass","4770" : "XLarge Hass" })

# %%
# convert Date column's format;

avo['Date'] =pd.to_datetime(avo.Date)

avo.sort_values(by=['Date'], inplace=True, ascending=True)

avo.head()
# Out:
#             Date  AveragePrice  Total Volume  Small Hass  Large Hass  \
# 11569 2015-01-04          1.75      27365.89     9307.34     3844.81
# 9593  2015-01-04          1.49      17723.17     1189.35    15628.27
# 10009 2015-01-04          1.68       2896.72      161.68      206.96
# 1819  2015-01-04          1.52      54956.80     3013.04    35456.88
# 9333  2015-01-04          1.64       1505.12        1.27     1129.50
#
#        XLarge Hass  Total Bags  Small Bags  Large Bags  XLarge Bags  \
# 11569       615.28    13598.46    13061.10      537.36          0.0
# 9593          0.00      905.55      905.55        0.00          0.0
# 10009         0.00     2528.08     2528.08        0.00          0.0
# 1819       1561.70    14925.18    11264.80     3660.38          0.0
# 9333          0.00      374.35      186.67      187.68          0.0
#
#                type  year              region
# 11569       organic  2015           Southeast
# 9593        organic  2015             Chicago
# 10009       organic  2015  HarrisburgScranton
# 1819   conventional  2015          Pittsburgh
# 9333        organic  2015               Boise

# %%
# Average price of Conventional Avocados over time

mask = avo['type']== 'conventional'
plt.rc('figure', titlesize=50)
fig = plt.figure(figsize = (26, 7))
fig.suptitle('Average Price of Conventional Avocados Over Time', fontsize=25)
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.93)

dates = avo[mask]['Date'].tolist()
avgPrices = avo[mask]['AveragePrice'].tolist()

plt.scatter(dates, avgPrices, c=avgPrices, cmap='plasma')
ax.set_xlabel('Date',fontsize = 15)
ax.set_ylabel('Average Price (USD)', fontsize = 15)
plt.show()

# %%
# Average price of Organic Avocados over time
mask = avo['type']== 'organic'
plt.rc('figure', titlesize=50)
fig = plt.figure(figsize = (26, 7))
fig.suptitle('Average Price of Organic Avocados Over Time', fontsize=25)
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.93)

dates = avo[mask]['Date'].tolist()
avgPrices = avo[mask]['AveragePrice'].tolist()

plt.scatter(dates, avgPrices, c=avgPrices, cmap='plasma')
ax.set_xlabel('Date',fontsize = 15)
ax.set_ylabel('Average Price (USD)', fontsize = 15)
plt.show()

# %%
# TIME SERIES ANALYSIS

# Since the data itself is a time series data, I first want to see time series analysis predictions, and then apply ML models.

# Creating a two-column dataset to use in time series analysis;

avo2 = avo[['Date', 'AveragePrice']]
avo2 = avo2.set_index('Date')

weekly_df = avo2.resample('W').mean()
w_df = weekly_df.reset_index().dropna()

w_df.sort_values(by=['Date'])
w_df.head()
# Out:
#         Date  AveragePrice
# 0 2015-01-04      1.301296
# 1 2015-01-11      1.370648
# 2 2015-01-18      1.391111
# 3 2015-01-25      1.397130
# 4 2015-02-01      1.247037

# %%
# Plotting the weekly average prices by month;

import matplotlib.dates as mdates


fig = plt.figure(figsize = (27, 7))
ax = plt.axes()
#set ticks every month
ax.xaxis.set_major_locator(mdates.MonthLocator())
#set major ticks format
ax.xaxis.set_major_formatter(mdates.DateFormatter('%b %d'))
plt.plot(w_df['Date'],w_df['AveragePrice'],color='b', linewidth=1)
plt.xlabel("2015-2018")
plt.ylabel("Avocado Price USD")
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ##### Now, Let's see what we get from Machine Learning Algorithms!

# %%
# Dropping the Date column (date format is not suitable for next level analysis (i.e. OHE))
avo = avo.drop(['Date'], axis = 1)

# %%
# Checking if the sample is balanced;
avo.groupby('region').size()
# Out:
# region
# Albany                 338
# Atlanta                338
# BaltimoreWashington    338
# Boise                  338
# Boston                 338
# BuffaloRochester       338
# California             338
# Charlotte              338
# Chicago                338
# CincinnatiDayton       338
# Columbus               338
# DallasFtWorth          338
# Denver                 338
# Detroit                338
# GrandRapids            338
# GreatLakes             338
# HarrisburgScranton     338
# HartfordSpringfield    338
# Houston                338
# Indianapolis           338
# Jacksonville           338
# LasVegas               338
# LosAngeles             338
# Louisville             338
# MiamiFtLauderdale      338
# Midsouth               338
# Nashville              338
# NewOrleansMobile       338
# NewYork                338
# Northeast              338
# NorthernNewEngland     338
# Orlando                338
# Philadelphia           338
# PhoenixTucson          338
# Pittsburgh             338
# Plains                 338
# Portland               338
# RaleighGreensboro      338
# RichmondNorfolk        338
# Roanoke                338
# Sacramento             338
# SanDiego               338
# SanFrancisco           338
# Seattle                338
# SouthCarolina          338
# SouthCentral           338
# Southeast              338
# Spokane                338
# StLouis                338
# Syracuse               338
# Tampa                  338
# TotalUS                338
# West                   338
# WestTexNewMexico       335
# dtype: int64

# %% [markdown]
# Approximately, there are 338 observations from each region, sample seems balanced.

# %%
len(avo.region.unique())
# Out:
# 54

# %%
avo.region.unique()
# Out:
# array(['Southeast', 'Chicago', 'HarrisburgScranton', 'Pittsburgh',
#        'Boise', 'WestTexNewMexico', 'LosAngeles', 'LasVegas', 'Atlanta',
#        'DallasFtWorth', 'MiamiFtLauderdale', 'Plains', 'StLouis',
#        'Syracuse', 'Midsouth', 'Sacramento', 'Boston', 'Charlotte',
#        'Spokane', 'Albany', 'Houston', 'SouthCarolina', 'SanFrancisco',
#        'TotalUS', 'RaleighGreensboro', 'BuffaloRochester',
#        'NorthernNewEngland', 'GrandRapids', 'Denver', 'SanDiego',
#        'BaltimoreWashington', 'Roanoke', 'RichmondNorfolk', 'Northeast',
#        'SouthCentral', 'GreatLakes', 'Louisville', 'Seattle',
#        'CincinnatiDayton', 'NewYork', 'NewOrleansMobile', 'Indianapolis',
#        'Jacksonville', 'Columbus', 'Detroit', 'Philadelphia',
#        'PhoenixTucson', 'Nashville', 'Portland', 'HartfordSpringfield',
#        'Tampa', 'Orlando', 'West', 'California'], dtype=object)

# %% [markdown]
# There are 54 regions but some are subsets of the other regions, i.e: San Francisco-California

# %%
# basically we can remove states and work on cities rather than analysing both (to prevent multicollinerarity)

regionsToRemove = ['California', 'GreatLakes', 'Midsouth', 'NewYork', 'Northeast', 'SouthCarolina', 'Plains', 'SouthCentral', 'Southeast', 'TotalUS', 'West']
avo = avo[~avo.region.isin(regionsToRemove)]
len(avo.region.unique())
# Out:
# 43

# %%
# The average prices by regions

plt.figure(figsize=(10,11))
plt.title("Avg.Price of Avocado by Region")
Av= sns.barplot(x="AveragePrice",y="region",data= avo)

# %%
type_counts = avo.groupby('type').size()
print(type_counts)
# Out:
# type
# conventional    7267
# organic         7264
# dtype: int64

# %% [markdown]
# Types of avocados are also balanced since the ratio is almost 0.5

# %%
# The average prices of avocados by types; organic or not

plt.figure(figsize=(5,7))
plt.title("Avg.Price of Avocados by Type")
Av= sns.barplot(x="type",y="AveragePrice",data= avo)

# %%
# Total Bags = Small Bags + Large Bags + XLarge Bags

# To avoid multicollinearity I'll keep S-L-XL bags and drop Total Bags

# But before droping we'd better to see the correlation between those columns:

avo[['Small Hass', "Large Hass", "XLarge Hass",'Small Bags','Large Bags','XLarge Bags','Total Volume','Total Bags']].corr()
# Out:
#               Small Hass  Large Hass  XLarge Hass  Small Bags  Large Bags  \
# Small Hass      1.000000    0.505321     0.412247    0.653724    0.348216
# Large Hass      0.505321    1.000000     0.580107    0.563730    0.265454
# XLarge Hass     0.412247    0.580107     1.000000    0.437290    0.121320
# Small Bags      0.653724    0.563730     0.437290    1.000000    0.238270
# Large Bags      0.348216    0.265454     0.121320    0.238270    1.000000
# XLarge Bags     0.454440    0.308823     0.492822    0.658700    0.080479
# Total Volume    0.890380    0.787495     0.576676    0.836906    0.429051
# Total Bags      0.684041    0.577115     0.429245    0.956905    0.509324
#
#               XLarge Bags  Total Volume  Total Bags
# Small Hass       0.454440      0.890380    0.684041
# Large Hass       0.308823      0.787495    0.577115
# XLarge Hass      0.492822      0.576676    0.429245
# Small Bags       0.658700      0.836906    0.956905
# Large Bags       0.080479      0.429051    0.509324
# XLarge Bags      1.000000      0.549505    0.622964
# Total Volume     0.549505      1.000000    0.869796
# Total Bags       0.622964      0.869796    1.000000

# %%
plt.figure(figsize=(12,6))
sns.heatmap(avo.corr(),cmap='coolwarm',annot=True)

# darker = stronger
# Out:
# <Axes: >

# %% [markdown]
# There is a high correlation between those pairs:
#
# small hass & total volume  (0.89)
# total bags & total volume  (0.87)
# small bags & total bags    (0.96)
#
# Small Hass avocados are the most preferred/sold type in the US and customers tend to buy those avocados as bulk, not bag.
#
# Retailers want to increase the sales of bagged avocados instead of bulks. They think this is more advantageous for them.
#
# Total Bags variable has a very high correlation with Total Volume (Total Sales) and Small Bags, so we can say that most of the bagged sales comes from the small bags.

# %%
df_V = avo.drop(['AveragePrice', 'Total Volume', 'Total Bags'], axis = 1).groupby('year').agg('sum')
df_V
# Out:
#         Small Hass    Large Hass  XLarge Hass    Small Bags   Large Bags  \
# year
# 2015  3.956835e+08  3.816794e+08  34551068.97  1.424565e+08  28409959.31
# 2016  3.373537e+08  3.684409e+08  37822298.99  2.630756e+08  80734611.45
# 2017  3.667922e+08  3.405079e+08  22968983.86  2.811956e+08  93246243.70
# 2018  1.013592e+08  8.963867e+07   5804442.33  7.920550e+07  28310113.38
#
#       XLarge Bags
# year
# 2015   1324210.40
# 2016   4894984.66
# 2017   5384099.35
# 2018   1589371.50

# %%
indexes = ['Small Hass', 'Large Hass', 'XLarge Hass', 'Small Bags', 'Large Bags', 'XLarge Bags']
series = pd.DataFrame({'2015': df_V.loc[[2015],:].values.tolist()[0],
                      '2016': df_V.loc[[2016],:].values.tolist()[0],
                      '2017': df_V.loc[[2017],:].values.tolist()[0],
                      '2018': df_V.loc[[2018],:].values.tolist()[0]}, index=indexes)
series.plot.pie(y='2015',figsize=(9, 9), autopct='%1.1f%%', colors=['silver', 'pink', 'orange', 'palegreen', 'aqua', 'blue'], fontsize=18, legend=False, title='2015 Volume Distribution').set_ylabel('')
series.plot.pie(y='2016',figsize=(9, 9), autopct='%1.1f%%', colors=['silver', 'pink', 'orange', 'palegreen', 'aqua', 'blue'], fontsize=18, legend=False, title='2016 Volume Distribution').set_ylabel('')
series.plot.pie(y='2017',figsize=(9, 9), autopct='%1.1f%%', colors=['silver', 'pink', 'orange', 'palegreen', 'aqua', 'blue'], fontsize=18, legend=False, title='2017 Volume Distribution').set_ylabel('')
series.plot.pie(y='2018',figsize=(9, 9), autopct='%1.1f%%', colors=['silver', 'pink', 'orange', 'palegreen', 'aqua', 'blue'], fontsize=18, legend=False, title='2018 Volume Distribution').set_ylabel('')
# Out:
# Text(0, 0.5, '')

# %%
# Total Bags = Small Bags + Large Bags + XLarge Bags

avo = avo.drop(['Total Bags'], axis = 1)

# %%
# Total Volume = Small Hass +Large Hass +XLarge Hass + Total Bags , to avoid multicollinearity I also drop Total Volume column.


avo = avo.drop(['Total Volume'], axis = 1)

# %%
avo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14531 entries, 9593 to 8574
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   AveragePrice  14531 non-null  float64
#  1   Small Hass    14531 non-null  float64
#  2   Large Hass    14531 non-null  float64
#  3   XLarge Hass   14531 non-null  float64
#  4   Small Bags    14531 non-null  float64
#  5   Large Bags    14531 non-null  float64
#  6   XLarge Bags   14531 non-null  float64
#  7   type          14531 non-null  object
#  8   year          14531 non-null  int64
#  9   region        14531 non-null  object
# dtypes: float64(7), int64(1), object(2)
# memory usage: 1.7+ MB

# %% [markdown]
# ### Correlation between target variable and independent variables.

# %%
# Checking correlation between features and the target
corr = avo.corr()
corr
# Out:
#               AveragePrice  Small Hass  Large Hass  XLarge Hass  Small Bags  Large Bags  \
# AveragePrice      1.000000   -0.411982   -0.365340    -0.253495   -0.328867   -0.335109
# Small Hass       -0.411982    1.000000    0.505321     0.412247    0.653724    0.348216
# Large Hass       -0.365340    0.505321    1.000000     0.580107    0.563730    0.265454
# XLarge Hass      -0.253495    0.412247    0.580107     1.000000    0.437290    0.121320
# Small Bags       -0.328867    0.653724    0.563730     0.437290    1.000000    0.238270
# Large Bags       -0.335109    0.348216    0.265454     0.121320    0.238270    1.000000
# XLarge Bags      -0.158155    0.454440    0.308823     0.492822    0.658700    0.080479
# year              0.094148   -0.001381   -0.019325    -0.054538    0.109127    0.149575
#
#               XLarge Bags      year
# AveragePrice    -0.158155  0.094148
# Small Hass       0.454440 -0.001381
# Large Hass       0.308823 -0.019325
# XLarge Hass      0.492822 -0.054538
# Small Bags       0.658700  0.109127
# Large Bags       0.080479  0.149575
# XLarge Bags      1.000000  0.098566
# year             0.098566  1.000000

# %%
# Visualizing corralation matrix by plotting heatmap
plt.figure(figsize = (20, 15))
sns.heatmap(avo.corr(),linewidths = 0.1, fmt = ".1g", linecolor = "Black", annot = True, cmap = "Blues_r")
plt.yticks(rotation = 0)
plt.show()

# %%
# Standardizing (scaling) the variables

from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
avo.loc[:,'Small Hass':'XLarge Bags']= scaler.fit_transform(avo.loc[:,'Small Hass':'XLarge Bags']) 
avo.head()
# Out:
#        AveragePrice  Small Hass  Large Hass  XLarge Hass  Small Bags  Large Bags  XLarge Bags  \
# 9593           1.49   -0.402608   -0.475043    -0.347233   -0.419915   -0.371357    -0.231149
# 10009          1.68   -0.407686   -0.586724    -0.347233   -0.406763   -0.371357    -0.231149
# 1819           1.52   -0.393596   -0.331445    -0.269328   -0.335946   -0.285739    -0.231149
# 9333           1.64   -0.408479   -0.580043    -0.347233   -0.425742   -0.366967    -0.231149
# 2807           0.75    1.700946    0.483289     0.414395    0.911829   -0.305594    -0.231149
#
#                type  year              region
# 9593        organic  2015             Chicago
# 10009       organic  2015  HarrisburgScranton
# 1819   conventional  2015          Pittsburgh
# 9333        organic  2015               Boise
# 2807   conventional  2015    WestTexNewMexico

# %%
# Specifying dependent and independent variables

X = avo.drop(['AveragePrice'], axis = 1)
y = avo['AveragePrice']
y=np.log1p(y)

# %%
# Specifying dependent and independent variables

X = avo.drop(['AveragePrice'], axis = 1)
y = avo['AveragePrice']
y=np.log1p(y)

# %%
# Labeling the categorical variables

Xcat=pd.get_dummies(X[["type","region"]], drop_first = True)

# %%
Xnum=X[["Small Hass","Large Hass","XLarge Hass","Small Bags","Large Bags","XLarge Bags"]]

# %%
X= pd.concat([Xcat, Xnum], axis = 1) # Concatenate dummy categorcal variables and numeric variables
X.shape
# Out:
# (14531, 49)

# %%
F_DF = pd.concat([y,X],axis=1)
F_DF.head(2)
# Out:
#        AveragePrice  type_organic  region_Atlanta  region_BaltimoreWashington  region_Boise  \
# 9593       0.912283             1               0                           0             0
# 10009      0.985817             1               0                           0             0
#
#        region_Boston  region_BuffaloRochester  region_Charlotte  region_Chicago  \
# 9593               0                        0                 0               1
# 10009              0                        0                 0               0
#
#        region_CincinnatiDayton  ...  region_StLouis  region_Syracuse  region_Tampa  \
# 9593                         0  ...               0                0             0
# 10009                        0  ...               0                0             0
#
#        region_WestTexNewMexico  Small Hass  Large Hass  XLarge Hass  Small Bags  Large Bags  \
# 9593                         0   -0.402608   -0.475043    -0.347233   -0.419915   -0.371357
# 10009                        0   -0.407686   -0.586724    -0.347233   -0.406763   -0.371357
#
#        XLarge Bags
# 9593     -0.231149
# 10009    -0.231149
#
# [2 rows x 50 columns]

# %%
# Just before the regression analysis, I want to visualise the highly correlated Variables with the Average Prices;

sns.set(color_codes=True)
sns.jointplot(x="Small Hass", y="AveragePrice", data=F_DF, kind="reg");
sns.jointplot(x="Small Bags", y="AveragePrice", data=F_DF, kind="reg");
sns.jointplot(x="Large Bags", y="AveragePrice", data=F_DF, kind="reg");

# %%
sns.lmplot(x="Small Hass", y="AveragePrice", col="type_organic", data=F_DF, col_wrap=2);

# %% [markdown]
# Graphs depict that organic avocados have less elasticity to the price, compared to conventional ones.

# %%
# TRAIN and TEST SPLIT

# Since the data is a time series data (gives weekly avocado prices between Jan 2015 and Apr 2018)
# I sort it by Date and then split it due to date manually (not randomly), to preserve the 'times series effect' on it.
# I determined the split ratio as 0.30, so train and test data are just as follows;


X_train=X[0:10172]
y_train=y[0:10172]
X_test=X[10172:]
y_test=y[10172:]

# %% [markdown]
# # Implementing machine learning models

# %% [markdown]
# ### Multiple Linear Regression

# %%
from sklearn.linear_model import LinearRegression

LinReg = LinearRegression()
LinReg.fit(X_train,y_train)

print ("R2 of Linear Regresson:", LinReg.score(X_train,y_train) )
# Out:
# R2 of Linear Regresson: 0.645621531668498

# %%
# Import model related library
from sklearn import metrics
from sklearn.metrics import mean_squared_error
from sklearn import svm

# %%
print('MAE: ',metrics.mean_absolute_error(y_test, LinReg.predict(X_test)))
print('MSE: ',metrics.mean_squared_error(y_test, LinReg.predict(X_test)))
print('RMSE:',np.sqrt(metrics.mean_squared_error(y_test, LinReg.predict(X_test))))
# Out:
# MAE:  0.11297102534788969
# MSE:  0.020701387918018035
# RMSE: 0.14387976896707208

# %%
# Creating a Histogram of Residuals
plt.figure(figsize=(6,4))
sns.distplot(y_test - LinReg.predict(X_test))
plt.title('Distribution of residuals');

# %%
plt.scatter(y_test,LinReg.predict(X_test))

# %%
# we can confirm the R2 value (moreover, get the R2 Adj.value) of the model by statsmodels library of python
import statsmodels.api as sm
X_train = sm.add_constant(X_train) # adding a constant
model = sm.OLS(y_train, X_train).fit()
print(model.summary())
# Out:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:           AveragePrice   R-squared:                       0.646
# Model:                            OLS   Adj. R-squared:                  0.644
# Method:                 Least Squares   F-statistic:                     376.3
# Date:                Sun, 06 Aug 2023   Prob (F-statistic):               0.00
# Time:                        15:03:33   Log-Likelihood:                 9124.8
# No. Observations:               10172   AIC:                        -1.815e+04
# Df Residuals:                   10122   BIC:                        -1.779e+04
# Df Model:                          49
# Covariance Type:            nonrobust
# ==============================================================================================
#                                  coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------------------
# const                          0.8247      0.007    126.290      0.000       0.812       0.838
# type_organic                   0.1741      0.003     63.092      0.000       0.169       0.180
# region_Atlanta                -0.0971      0.009    -10.558      0.000      -0.115      -0.079
# region_BaltimoreWashington     0.0131      0.009      1.384      0.166      -0.005       0.032
# region_Boise                  -0.1413      0.009    -15.484      0.000      -0.159      -0.123
# region_Boston                 -0.0081      0.009     -0.868      0.386      -0.026       0.010
# region_BuffaloRochester       -0.0022      0.009     -0.241      0.809      -0.020       0.016
# region_Charlotte              -0.0056      0.009     -0.610      0.542      -0.024       0.012
# region_Chicago                 0.0009      0.010      0.092      0.927      -0.019       0.020
# region_CincinnatiDayton       -0.1724      0.009    -18.735      0.000      -0.190      -0.154
# region_Columbus               -0.1442      0.009    -15.808      0.000      -0.162      -0.126
# region_DallasFtWorth          -0.1891      0.009    -20.132      0.000      -0.208      -0.171
# region_Denver                 -0.1165      0.010    -11.885      0.000      -0.136      -0.097
# region_Detroit                -0.1419      0.009    -15.114      0.000      -0.160      -0.123
# region_GrandRapids            -0.0348      0.009     -3.819      0.000      -0.053      -0.017
# region_HarrisburgScranton     -0.0138      0.009     -1.519      0.129      -0.032       0.004
# region_HartfordSpringfield     0.0978      0.009     10.678      0.000       0.080       0.116
# region_Houston                -0.1972      0.009    -20.942      0.000      -0.216      -0.179
# region_Indianapolis           -0.0998      0.009    -10.954      0.000      -0.118      -0.082
# region_Jacksonville           -0.0497      0.009     -5.448      0.000      -0.068      -0.032
# region_LasVegas               -0.0907      0.009     -9.931      0.000      -0.109      -0.073
# region_LosAngeles             -0.1037      0.011     -9.599      0.000      -0.125      -0.083
# region_Louisville             -0.1340      0.009    -14.717      0.000      -0.152      -0.116
# region_MiamiFtLauderdale      -0.0530      0.009     -5.739      0.000      -0.071      -0.035
# region_Nashville              -0.1634      0.009    -17.889      0.000      -0.181      -0.145
# region_NewOrleansMobile       -0.1220      0.009    -13.346      0.000      -0.140      -0.104
# region_NorthernNewEngland     -0.0258      0.009     -2.808      0.005      -0.044      -0.008
# region_Orlando                -0.0335      0.009     -3.667      0.000      -0.051      -0.016
# region_Philadelphia            0.0447      0.009      4.873      0.000       0.027       0.063
# region_PhoenixTucson          -0.1256      0.009    -13.254      0.000      -0.144      -0.107
# region_Pittsburgh             -0.0685      0.009     -7.523      0.000      -0.086      -0.051
# region_Portland               -0.1236      0.009    -13.363      0.000      -0.142      -0.105
# region_RaleighGreensboro      -0.0342      0.009     -3.723      0.000      -0.052      -0.016
# region_RichmondNorfolk        -0.1214      0.009    -13.334      0.000      -0.139      -0.104
# region_Roanoke                -0.1548      0.009    -17.003      0.000      -0.173      -0.137
# region_Sacramento              0.0210      0.009      2.296      0.022       0.003       0.039
# region_SanDiego               -0.0938      0.009    -10.258      0.000      -0.112      -0.076
# region_SanFrancisco            0.1044      0.009     11.080      0.000       0.086       0.123
# region_Seattle                -0.0715      0.009     -7.720      0.000      -0.090      -0.053
# region_Spokane                -0.0937      0.009    -10.277      0.000      -0.112      -0.076
# region_StLouis                -0.0934      0.009    -10.229      0.000      -0.111      -0.075
# region_Syracuse               -0.0048      0.009     -0.528      0.598      -0.023       0.013
# region_Tampa                  -0.0739      0.009     -8.069      0.000      -0.092      -0.056
# region_WestTexNewMexico       -0.1203      0.009    -12.907      0.000      -0.139      -0.102
# Small Hass                    -0.0146      0.002     -9.553      0.000      -0.018      -0.012
# Large Hass                    -0.0176      0.002     -9.296      0.000      -0.021      -0.014
# XLarge Hass                   -0.0005      0.002     -0.298      0.766      -0.003       0.003
# Small Bags                    -0.0038      0.002     -2.098      0.036      -0.007      -0.000
# Large Bags                    -0.0159      0.001    -11.435      0.000      -0.019      -0.013
# XLarge Bags                    0.0114      0.002      6.423      0.000       0.008       0.015
# ==============================================================================
# Omnibus:                      354.259   Durbin-Watson:                   1.659
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              845.629
# Skew:                          -0.180   Prob(JB):                    2.37e-184
# Kurtosis:                       4.366   Cond. No.                         76.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.

# %%
X_train=X[0:10172]
y_train=y[0:10172]
X_test=X[10172:]
y_test=y[10172:]

# %%
# LASSO and RIDGE Regressions

from sklearn import linear_model
from sklearn.model_selection import GridSearchCV

alphas = np.logspace(-5,3,20)

clf = GridSearchCV(estimator=linear_model.Ridge(), param_grid=dict(alpha=alphas), cv=10)
clf.fit(X_train, y_train)
optlamGSCV_R = clf.best_estimator_.alpha
print('Optimum regularization parameter (Ridge):', optlamGSCV_R)

clf = GridSearchCV(estimator=linear_model.Lasso(), param_grid=dict(alpha=alphas), cv=10)
clf.fit(X_train, y_train)
optlamGSCV_L= clf.best_estimator_.alpha
print('Optimum regularization parameter (Lasso):', optlamGSCV_L)
# Out:
# Optimum regularization parameter (Ridge): 1.1288378916846884
# Optimum regularization parameter (Lasso): 1e-05

# %%
ridge = linear_model.Ridge(alpha = optlamGSCV_R) 
ridge.fit(X_train, y_train)
print('RMSE value of the Ridge Model is: ',np.sqrt(metrics.mean_squared_error(y_test, ridge.predict(X_test))))
# Out:
# RMSE value of the Ridge Model is:  0.1437104320516621

# %%
ridge.score(X_train, y_train) #Returns the coefficient of determination (R2) of the prediction.
# Out:
# 0.6454885606690974

# %%
# Creating a Histogram of Residuals
plt.figure(figsize=(6,4))
sns.distplot(y_test - ridge.predict(X_test))
plt.title('Distribution of residuals');

# %%
lasso = linear_model.Lasso(alpha = optlamGSCV_L)
lasso.fit(X_train, y_train)
print('RMSE value of the Lasso Model is: ',np.sqrt(metrics.mean_squared_error(y_test, lasso.predict(X_test))))
# Out:
# RMSE value of the Lasso Model is:  0.1437498061034761

# %%
# Creating a Histogram of Residuals
plt.figure(figsize=(6,4))
sns.distplot(y_test - lasso.predict(X_test))
plt.title('Distribution of residuals');

# %%
coef = pd.Series(lasso.coef_, index = X_train.columns)
print("Lasso picked " + str(sum(coef != 0)) + " variables and eliminated the other " +  
      str(sum(coef == 0)) + " variables")
imp_coef = pd.concat([coef.sort_values()]) #plot all
plt.rcParams['figure.figsize'] = (7.0, 30.0)
imp_coef.plot(kind = "barh")
plt.title("Coefficients in the Lasso Model")
# Out:
# Lasso picked 49 variables and eliminated the other 0 variables
# Text(0.5, 1.0, 'Coefficients in the Lasso Model')

# %% [markdown]
# According to the RMSE results, Ridge works best compared to linear regression and lasso.
#
# Let's see the other ML Models' RMSE values;

# %% [markdown]
# # KNN Regressor

# %%
from sklearn import neighbors
from math import sqrt

Knn = neighbors.KNeighborsRegressor()
Knn.fit(X_train, y_train)  
error = sqrt(metrics.mean_squared_error( y_test, Knn.predict(X_test))) 
print('RMSE value of the KNN Model is:', error)
# Out:
# RMSE value of the KNN Model is: 0.14178100684761086

# %%
Knn.score(X_train, y_train)  # R2 of the KNN model
# Out:
# 0.9274204661840991

# %% [markdown]
# # SVR Regressor

# %%
from sklearn.svm import SVR

# First, let's choose which kernel is the best for our data

for k in ['linear','poly','rbf','sigmoid']:
    clf = svm.SVR(kernel=k)
    clf.fit(X_train, y_train)
    confidence = clf.score(X_train, y_train)
    print(k,confidence)
# Out:
# linear 0.642019887912252
# poly 0.7666695753741131
# rbf 0.7948267556500271
# sigmoid -912617.2153032972

# %%
Svr=SVR(kernel='rbf', C=1, gamma= 0.5)   # Parameter Tuning to get the best accuracy

Svr.fit(X_train,y_train)
print(Svr.score(X_train,y_train))
# Out:
# 0.8208087046642912

# %% [markdown]
# ->Intuitively, the gamma defines how far the influence of a single training example reaches, with low values meaning ‘far’ and high values meaning ‘close’.
#
# -> The C parameter trades off correct classification of training examples against maximization of the decision function’s margin.
#
# -> For larger values of C, a smaller margin will be accepted if the decision function is better at classifying all training points correctly.
#
# -> A lower C will encourage a larger margin, therefore a simpler decision function, at the cost of training accuracy.
#
# -> In other words C behaves as a regularization parameter in the SVM.

# %%
error = sqrt(metrics.mean_squared_error(y_test,Svr.predict(X_test))) #calculate rmse
print('RMSE value of the SVR Model is:', error)
# Out:
# RMSE value of the SVR Model is: 0.13546519706088878

# %%
Svr.predict(X_test)[0:5]  # print the first 5 predictions of our test set
# Out:
# array([0.68179698, 0.84145673, 0.89931862, 0.99810732, 1.15107343])

# %%
y_test[0:5]
# Out:
# 16687    0.783902
# 14938    0.779325
# 16157    0.928219
# 15521    1.098612
# 15680    1.280934
# Name: AveragePrice, dtype: float64

# %% [markdown]
# # Decision Tree Regressor

# %%
# Determining the best depth
from sklearn.tree import DecisionTreeRegressor

minDepth = 100
minRMSE = 100000


for depth in range(2,10):
  tree_reg = DecisionTreeRegressor(max_depth=depth)
  tree_reg.fit(X_train, y_train)
  y_pred = tree_reg.predict(X_test)
  mse = mean_squared_error(y_test, y_pred)
  rmse = np.sqrt(mse)
  print("Depth:",depth,", MSE:", mse)
  print("Depth:",depth, ",RMSE:", rmse)
  
  if rmse < minRMSE:
    minRMSE = rmse
    minDepth = depth
    
      
print("MinDepth:", minDepth)
print("MinRMSE:", minRMSE)
# Out:
# Depth: 2 , MSE: 0.02393159453836313
# Depth: 2 ,RMSE: 0.1546983986289552
# Depth: 3 , MSE: 0.02505843106630313
# Depth: 3 ,RMSE: 0.15829855042388458
# Depth: 4 , MSE: 0.02614387451172003
# Depth: 4 ,RMSE: 0.1616906754012736
# Depth: 5 , MSE: 0.026029975970581452
# Depth: 5 ,RMSE: 0.16133807972881495
# Depth: 6 , MSE: 0.025390015786946912
# Depth: 6 ,RMSE: 0.15934244816415655
# Depth: 7 , MSE: 0.025397662261867085
# Depth: 7 ,RMSE: 0.15936644019951968
# Depth: 8 , MSE: 0.024499852672938915
# Depth: 8 ,RMSE: 0.1565242878052442
# Depth: 9 , MSE: 0.024462030982320762
# Depth: 9 ,RMSE: 0.15640342381904804
# MinDepth: 2
# MinRMSE: 0.1546983986289552

# %%
DTree=DecisionTreeRegressor(max_depth=minDepth)
DTree.fit(X_train,y_train)
print(DTree.score(X_train,y_train))
# Out:
# 0.5532570096878549

# %%
print('MAE:', metrics.mean_absolute_error(y_test, DTree.predict(X_test)))
print('MSE:', metrics.mean_squared_error(y_test, DTree.predict(X_test)))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, DTree.predict(X_test))))
# Out:
# MAE: 0.12232154747783433
# MSE: 0.023931594538363177
# RMSE: 0.15469839862895535

# %%
import six
import sys
sys.modules['sklearn.externals.six'] = six
from sklearn.externals.six import StringIO  
from IPython.display import Image  
from sklearn.tree import export_graphviz
import pydotplus
dot_data = StringIO()
export_graphviz(DTree, out_file=dot_data, feature_names = X.columns, 
                filled=True, rounded=True,
                special_characters=True)
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
Image(graph.create_png())  

# We obtain a 2 depth figure :)

# %%
conda install graphviz
# Out:
# Retrieving notices: ...working... done
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.3.1
#   latest version: 23.7.2
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.7.2
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\vkojh\anaconda3
#
#   added / updated specs:
#     - graphviz
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.73.0           |      h2bbff1b_12          16 KB
#     ca-certificates-2023.05.30 |       haa95532_0         120 KB
#     cairo-1.16.0               |       haedb8bc_5         1.9 MB
#     certifi-2023.7.22          |  py310haa95532_0         154 KB
#     expat-2.4.9                |       h6c2663c_0         207 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       hc0defaf_1         198 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     fribidi-1.0.10             |       h62dcd97_0          63 KB
#     getopt-win32-0.1           |       h2bbff1b_0          19 KB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     graphviz-2.50.0            |       h7eca76f_1        1007 KB
#     gts-0.7.6                  |       h63ab5a1_3         181 KB
#     harfbuzz-4.3.0             |       hb646838_1         855 KB
#     libboost-1.73.0            |      h6c2663c_12        20.1 MB
#     libgd-2.3.3                |       hd77b12b_2         350 KB
#     openssl-1.1.1v             |       h2bbff1b_0         5.5 MB
#     pango-1.50.7               |       h78c2152_0         279 KB
#     pixman-0.40.0              |       h2bbff1b_1         402 KB
#     poppler-22.12.0            |       h268424c_0         2.4 MB
#     poppler-data-0.4.11        |       haa95532_1         432 KB
#     ------------------------------------------------------------
#                                            Total:        36.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          pkgs/main/win-64::boost-cpp-1.73.0-h2bbff1b_12
#   cairo              pkgs/main/win-64::cairo-1.16.0-haedb8bc_5
#   expat              pkgs/main/win-64::expat-2.4.9-h6c2663c_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.14.1-hc0defaf_1
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/win-64::fribidi-1.0.10-h62dcd97_0
#   getopt-win32       pkgs/main/win-64::getopt-win32-0.1-h2bbff1b_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   graphviz           pkgs/main/win-64::graphviz-2.50.0-h7eca76f_1
#   gts                pkgs/main/win-64::gts-0.7.6-h63ab5a1_3
#   harfbuzz           pkgs/main/win-64::harfbuzz-4.3.0-hb646838_1
#   libboost           pkgs/main/win-64::libboost-1.73.0-h6c2663c_12
#   libgd              pkgs/main/win-64::libgd-2.3.3-hd77b12b_2
#   pango              pkgs/main/win-64::pango-1.50.7-h78c2152_0
#   pixman             pkgs/main/win-64::pixman-0.40.0-h2bbff1b_1
#   poppler            pkgs/main/win-64::poppler-22.12.0-h268424c_0
#   poppler-data       pkgs/main/win-64::poppler-data-0.4.11-haa95532_1
#
# The following packages will be UPDATED:
#
#   ca-certificates                     2023.01.10-haa95532_0 --> 2023.05.30-haa95532_0
#   certifi                         2022.12.7-py310haa95532_0 --> 2023.7.22-py310haa95532_0
#   openssl                                 1.1.1t-h2bbff1b_0 --> 1.1.1v-h2bbff1b_0
#
#
#
# Downloading and Extracting Packages
#
# graphviz-2.50.0      | 1007 KB   |            |   0%
#
# font-ttf-dejavu-sans | 335 KB    |            |   0%
#
#
# fontconfig-2.14.1    | 198 KB    |            |   0%
#
#
#
# poppler-22.12.0      | 2.4 MB    |            |   0%
#
#
#
#
# expat-2.4.9          | 207 KB    |            |   0%
#
#
#
#
#
# pango-1.50.7         | 279 KB    |            |   0%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    |            |   0%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.73.0     | 16 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 91 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# poppler-22.12.0      | 2.4 MB    |            |   1%
#
#
#
#
# expat-2.4.9          | 207 KB    | 7          |   8%
#
# font-ttf-dejavu-sans | 335 KB    | 4          |   5%
# graphviz-2.50.0      | 1007 KB   | 1          |   2%
#
#
# fontconfig-2.14.1    | 198 KB    | 8          |   8%
#
#
#
# poppler-22.12.0      | 2.4 MB    | #4         |  15%
# graphviz-2.50.0      | 1007 KB   | 6          |   6%
#
# font-ttf-dejavu-sans | 335 KB    | ##3        |  24%
#
#
#
# poppler-22.12.0      | 2.4 MB    | ##9        |  29%
#
#
#
#
# expat-2.4.9          | 207 KB    | ########## | 100%
#
#
#
#
# expat-2.4.9          | 207 KB    | ########## | 100%
#
#
#
#
#
# pango-1.50.7         | 279 KB    | 5          |   6%
#
#
#
#
#
# pango-1.50.7         | 279 KB    | #1         |  11%
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ###4       |  34%
#
#
#
# poppler-22.12.0      | 2.4 MB    | ####       |  40%
# graphviz-2.50.0      | 1007 KB   | 9          |  10%
#
# font-ttf-dejavu-sans | 335 KB    | ###8       |  38%
#
#
# fontconfig-2.14.1    | 198 KB    | ##4        |  24%
#
#
#
# poppler-22.12.0      | 2.4 MB    | #####4     |  54%
# graphviz-2.50.0      | 1007 KB   | ##         |  21%
#
# font-ttf-dejavu-sans | 335 KB    | ######6    |  67%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    |            |   1%
#
#
# fontconfig-2.14.1    | 198 KB    | ########9  |  89%
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ########## | 100%
#
#
#
#
#
# pango-1.50.7         | 279 KB    | ########## | 100%
#
#
#
# poppler-22.12.0      | 2.4 MB    | ######4    |  64%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | 1          |   2%
#
# font-ttf-dejavu-sans | 335 KB    | ########1  |  81%
# graphviz-2.50.0      | 1007 KB   | ##7        |  27%
#
#
#
# poppler-22.12.0      | 2.4 MB    | ########4  |  85%
#
# font-ttf-dejavu-sans | 335 KB    | ########## | 100%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #          |  11%
# graphviz-2.50.0      | 1007 KB   | ###6       |  37%
#
#
#
# poppler-22.12.0      | 2.4 MB    | #########7 |  97%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #4         |  15%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | 2          |   2%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | 8          |   9%
# graphviz-2.50.0      | 1007 KB   | ####2      |  43%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ###        |  30%
#
#
# fontconfig-2.14.1    | 198 KB    | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ##4        |  24%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | ########8  |  88%
# graphviz-2.50.0      | 1007 KB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   |            |   0%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   |            |   1%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ###6       |  37%
# graphviz-2.50.0      | 1007 KB   | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | 4          |   5%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | 9          |   9%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ####6      |  46%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #####2     |  52%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 1          |   2%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | ##7        |  27%
# graphviz-2.50.0      | 1007 KB   | #######4   |  75%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | #####6     |  56%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 2          |   3%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | #####      |  50%
# graphviz-2.50.0      | 1007 KB   | ########5  |  86%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ######8    |  68%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 4          |   4%
#
#
#
# poppler-22.12.0      | 2.4 MB    | ########## | 100%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ######5    |  65%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | #######3   |  73%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 5          |   6%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.73.0     | 16 KB     | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     | ########6  |  86%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 6          |   7%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ########6  |  87%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ########## | 100%
#
#
#
#
#
#
#
# font-ttf-source-code | 654 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 91 KB     | #7         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 7          |   8%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #6         |  17%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 350 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 8          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
# boost-cpp-1.73.0     | 16 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | 3          |   4%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ##8        |  28%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# getopt-win32-0.1     | 19 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | #8         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# graphite2-1.3.14     | 91 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #          |  10%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | ####1      |  42%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | #####1     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ####3      |  43%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #1         |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | #########5 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | #####9     |  59%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ######3    |  64%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #2         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | #######4   |  74%
# graphviz-2.50.0      | 1007 KB   | ########## | 100%
# graphviz-2.50.0      | 1007 KB   | ########## | 100%
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #3         |  14%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# certifi-2023.7.22    | 154 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #########3 |  94%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #5         |  16%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #7         |  17%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# poppler-data-0.4.11  | 432 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #8         |  18%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #9         |  19%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##1        |  22%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##3        |  23%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##4        |  24%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##5        |  25%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##6        |  27%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##7        |  28%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##8        |  29%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ##9        |  30%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###1       |  31%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###2       |  32%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###5       |  35%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###6       |  37%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ###9       |  40%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####2      |  43%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####3      |  44%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####5      |  45%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####6      |  47%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####8      |  48%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####      |  51%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####7     |  57%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####8     |  59%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #####9     |  60%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######     |  61%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######2    |  62%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######4    |  64%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######5    |  65%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######6    |  66%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######7    |  67%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ######8    |  69%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #######    |  70%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #######2   |  72%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #######6   |  77%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #######8   |  79%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########   |  81%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########2  |  83%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########4  |  85%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########6  |  87%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########8  |  89%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #########  |  91%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #########2 |  93%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #########4 |  95%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #########6 |  97%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | #########8 |  99%
#
#
#
#
#
#
#
#
#
# libboost-1.73.0      | 20.1 MB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done

# %%
from sklearn.ensemble import RandomForestRegressor
RForest = RandomForestRegressor()
RForest.fit(X_train,y_train)
print(RForest.score(X_train,y_train))
# Out:
# 0.984828206947346

# %%
print('MAE:', metrics.mean_absolute_error(y_test, RForest.predict(X_test)))
print('MSE:', metrics.mean_squared_error(y_test, RForest.predict(X_test)))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, RForest.predict(X_test))))
# Out:
# MAE: 0.11443327938284377
# MSE: 0.02183064110312026
# RMSE: 0.14775195803481

# %% [markdown]
# ### CONCLUSION
#
# Comparing The RMSE Values Of The Models

# %%
# Linear Regression RMSE : 
print('RMSE value of the Linear Regr : ',round(np.sqrt(metrics.mean_squared_error(y_test, LinReg.predict(X_test))),4))

# Ridge RMSE             : 
print('RMSE value of the Ridge Model : ',round(np.sqrt(metrics.mean_squared_error(y_test, ridge.predict(X_test))),4))

# Lasso RMSE             : 
print('RMSE value of the Lasso Model : ',round(np.sqrt(metrics.mean_squared_error(y_test, lasso.predict(X_test))),4))

# KNN RMSE               : 
print('RMSE value of the KNN Model   : ',round(np.sqrt(metrics.mean_squared_error(y_test, Knn.predict(X_test))),4))

# SVR RMSE               : 
print('RMSE value of the SVR Model   : ',round(np.sqrt(metrics.mean_squared_error(y_test, Svr.predict(X_test))),4))

# Decision Tree RMSE     : 
print('RMSE value of the Decis Tree  : ',round(np.sqrt(metrics.mean_squared_error(y_test, DTree.predict(X_test))),4))

# Random Forest RMSE     : 
print('RMSE value of the Rnd Forest  : ',round(np.sqrt(metrics.mean_squared_error(y_test, RForest.predict(X_test))),4))
# Out:
# RMSE value of the Linear Regr :  0.1439
# RMSE value of the Ridge Model :  0.1437
# RMSE value of the Lasso Model :  0.1437
# RMSE value of the KNN Model   :  0.1418
# RMSE value of the SVR Model   :  0.1355
# RMSE value of the Decis Tree  :  0.1547
# RMSE value of the Rnd Forest  :  0.1478

# %% [markdown]
# ## Now, it's time to decide wheather you're interested in short term predictions or long term!
#
# ### When we analyse the results, due to the RMSE values, we see that:
#
# #### if we need longer periods prices, SVR model gives the best predicts. (coefficient of determination of 82%)
